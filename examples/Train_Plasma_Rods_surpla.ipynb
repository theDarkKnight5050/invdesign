# %%
import numpy as np
import autograd.numpy as npa
import matplotlib as mpl
mpl.rcParams['figure.dpi']=100
import matplotlib.pylab as plt
from autograd.scipy.signal import convolve as conv
from skimage.draw import circle
import ceviche
from ceviche import fdfd_ez, jacobian, fdfd_hz
from ceviche.optimizers import adam_optimize
from ceviche.modes import insert_mode
import collections
from make_gif import make_gif
# Create a container for our slice coords to be used for sources and probes
Slice = collections.namedtuple('Slice', 'x y')

# %%
#----------------- Simulation Constants -----------------#
# The angular frequencies
omega1=2*np.pi*200e12
# Wavevector
k0=omega1/299792458
# Spatial resolution in meters
dl=40e-9
# Number of pixels in x-direction
Nx=120
# Number of pixels in y-direction
Ny=120
# Number of pixels in the PMLs in each direction
Npml=20
# Minimum value of the relative permittivity
epsr_train_min=-12.0
epsr_train_max=1.0
# Maximum value of the relative permittivity
epsr_design=1.0
epsr_bckgd=12.0

#------------------- Domain Constants -------------------#
# Space between the PMLs and the design region (in pixels)
space=10
# Width of the waveguide (in pixels)
wg_width=12
# Length in pixels of the source/probe slices on each side of the center point
space_slice=8
# Number of dots in a row/column
num_dots=15
# Radius of dots
circle_rad=int((Nx-2*(Npml+space))/(2*num_dots))
# Lattice constant
ra=0.6

#---------------- Optimization Constants ----------------#
# Number of epochs in the optimization 
Nsteps=200
# Step size for the Adam optimizer
step_size=1e-3

#------------------ Graphing Constants ------------------#
Emax=0
emin=0
emax=0

# %%
def init_design(epsrs, Nx=Nx, Ny=Ny, Npml=Npml, space=space, num_dots=num_dots, circle_rad=circle_rad, ra=ra):
    # Selector for each plasma rod
    rods = [np.zeros((Nx, Ny)) for i in range(num_dots**2)]
    # Selector for entire design region
    design_region = np.zeros((Nx, Ny))
    design_region[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 1
    
    # Initialize selector for circular plasma rods
    center_x = Npml+space+circle_rad
    for i in range(num_dots):
        center_y = Npml+space+circle_rad
        for j in range(num_dots):
            r, c = circle(center_x, center_y, circle_rad*ra)
            rods[j + i*num_dots][r, c] = 1
            center_y = center_y + 2*circle_rad
        center_x = center_x + 2*circle_rad
        
    return rods, design_region
    
def init_guides(Nx=Nx, Ny=Ny, Npml=Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=9):
    """Initializes waveguides and sources

    space       : The space between the PML and the structure
    wg_width    : The feed and probe waveguide width
    space_slice : The added space for the probe and source slices
    """
    bg_rho = np.zeros((Nx, Ny))
        
    # Input waveguide
    bg_rho[Nx//2-wg_width//2:Ny//2+wg_width//2,0:int(Npml+space)] = 1
    # Data waveguide 1
    bg_rho[0:int(Npml+space),Ny//2-wg_width//2:Ny//2+wg_width//2] = 1
    
    # Input probe slice
    input_slice = Slice(x=np.arange(Nx//2-wg_width//2-space_slice, Nx//2+wg_width//2+space_slice),
                        y=np.array(Npml+1))
    # Data probe slice 
    data_slice = Slice(x=np.array(Npml+1),
                        y=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice))
    input_slices = [input_slice, data_slice]
    
    # Output waveguide
    bg_rho[int(Nx-Npml-space)::,Ny//2-wg_width//2:Ny//2+wg_width//2] = 1
    # Ground waveguide
    bg_rho[Nx//2-wg_width//2:Nx//2+wg_width//2,int(Ny-Npml-space)::] = 1
    
    # Output probe slice
    output_slice = Slice(x=np.array(Nx-Npml-1),
                         y=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice))
    #Ground probe slice
    ground_slice = Slice(x=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice),
                         y=np.array(Ny-Npml-1))
    output_slices = [output_slice, ground_slice]
            
    return bg_rho, input_slices, output_slices

def init_domain(epsrs):
    rods, design_region = init_design(epsrs)
    bg_rho, input_slices, output_slices = \
        init_guides(Nx, Ny, Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=9)
    return bg_rho, design_region, rods, input_slices, output_slices

# %%
# set the colormap and centre the colorbar
class MidpointNormalize(mpl.colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)

    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        mpl.colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))
    
def real(val, outline=None, ax=None, cbar=False, cmap='RdBu', outline_alpha=0.5, vmin=None, vmax=None):
    """Plots the real part of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)
    
    if vmin is None:
        vmax = np.real(val).max()
        vmin = np.real(val).min()
    h = ax.imshow(np.real(val.T), cmap=cmap, origin='lower left', clim=(vmin, vmax), \
                  norm=MidpointNormalize(midpoint=0,vmin=vmin,vmax=vmax))
    
    if outline is not None:
        ax.contour(outline.T, 0, colors='k', alpha=outline_alpha)
    
    ax.set_ylabel('y')
    ax.set_xlabel('x')
    if cbar:
        plt.colorbar(h, ax=ax)
    
    return ax

def abslt(val, outline=None, ax=None, cbar=False, cmap='magma', outline_alpha=0.5, outline_val=None, vmax=None):
    """Plots the absolute value of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)      
    
    if vmax is None:
        vmax = np.abs(val).max()
    h = ax.imshow(np.abs(val.T), cmap=cmap, origin='lower left', vmin=0, vmax=vmax)
    
    if outline_val is None and outline is not None: outline_val = 0.5*(outline.min()+outline.max())
    if outline is not None:
        ax.contour(outline.T, [outline_val], colors='w', alpha=outline_alpha)
    
    ax.set_ylabel('y')
    ax.set_xlabel('x')
    if cbar:
        plt.colorbar(h, ax=ax)
    
    return ax

# %%
def viz_sim(epsr, source, data, slices=[], log=0):
    """Solve and visualize a simulation with permittivity 'epsr'
    """
    global emin, emax, Emax
    
    simulation = fdfd_hz(omega1, dl, epsr, [Npml, Npml])
    Ex, _, _ = simulation.solve(data)
    
    epsr[epsr >= epsr_train_max] = epsr_train_max
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
    fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(16,4))
    ceviche.viz.abs(Ex, outline=epsr_graph, ax=axs[0], cbar=True)
    real(epsr, ax=axs[1], cmap='RdGy', cbar=True)
    for sl in slices:
        for ax in axs:
            try:
                ax.plot(sl.x*np.ones(len(sl.y)), sl.y, 'w-', alpha=0.5)
            except:
                ax.plot(sl.x, sl.y*np.ones(len(sl.x)), 'w-', alpha=0.5)
        
    if log:
        if np.abs(Ex).max() > Emax:
            Emax=np.abs(Ex).max()
        np.savetxt('spl/Ex_%03d.csv' % log, np.abs(Ex), delimiter=',')
        
        if epsr.min() < emin:
            emin=epsr.min()
        if epsr.max() > emax:
            emax=epsr.max()
        np.savetxt('spl/epsr_%03d.csv' % log, epsr, delimiter=',')
    
    return (simulation, axs, fig)

def mask_combine_rho(rods, bg_rho, design_region):
    """Utility function for combining the design region rho and the background rho
    """
    train = (epsr_train_max-epsr_train_min)*rods*(rods!=0).astype(np.float) + epsr_train_min*(rods!=0).astype(np.float)
    design = epsr_design*design_region*(rods==0).astype(np.float)
    bckgd = epsr_bckgd*bg_rho*(design_region==0).astype(np.float)
    return train + design + bckgd

def scale_epsrs(epsrs, rods):
    epsrs = epsrs.flatten()
    epsrs = npa.arctan(epsrs) / np.pi + 0.5 
    rho = np.zeros(rods[0].shape)
    for i in range(len(epsrs)):
        rho += epsrs[i]*rods[i]
    return rho

def epsr_parameterization(epsrs, bg_rho, design_region, rods):
    """Defines the parameterization steps for constructing rho
    """
    rods = scale_epsrs(epsrs, rods)
    return mask_combine_rho(rods, bg_rho, design_region)

# %%
# Initialize the parametrization rho and the design region
epsrs = np.ones((num_dots, num_dots))*1.9
bg_rho, design_region, rods, input_slices, output_slices = init_domain(epsrs)

# Compute the permittivity from the design_region and the plasma rod permittivities
epsr_init = epsr_parameterization(epsrs, bg_rho, design_region, rods)

# Setup sources
source = insert_mode(omega1, dl, input_slices[0].x, input_slices[0].y, epsr_init, m=1)
data = insert_mode(omega1, dl, input_slices[1].x, input_slices[1].y, epsr_init, m=1)

# Setup probes
probe = insert_mode(omega1, dl, output_slices[0].x, output_slices[0].y, epsr_init, m=1)
ground = insert_mode(omega1, dl, output_slices[1].x, output_slices[1].y, epsr_init, m=1)

# Simulate initial device
simulation, ax, fig = viz_sim(epsr_init, source, data, slices = input_slices + output_slices)

# %%
def callback_output_structure(iteration, of_list, epsrs):
    """Callback function to output fields and the structures (for making sweet gifs)"""
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    _, axs, fig = viz_sim(epsr, source, data, slices = input_slices + output_slices, log=iteration)
    plt.close()

# %%
# Define optimization objective
def mode_overlap(E1, E2):
    """Defines an overlap integral between the sim field and desired field
    """
    return npa.abs(npa.sum(npa.conj(E1)*E2))*1e6

# %%
Ex_0, _, _ = simulation.solve(data)
normal = mode_overlap(Ex_0, probe)

def objective(epsrs):
    """Objective function called by optimizer
    1) Takes the density distribution as input
    2) Constructs epsr
    2) Runs the simulation
    3) Returns the overlap integral between the output wg field 
       and the desired mode field
    """
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    simulation.eps_r = epsr

    Ex, _, _ = simulation.solve(data)
    return mode_overlap(Ex, probe) / normal
    
def simulate():
    # Compute the gradient of the objective function using revere-mode differentiation
    objective_jac = jacobian(objective, mode='reverse')

    # Maximize the objective function using an ADAM optimizer
    epsrs_optimum, _ = adam_optimize(objective, epsrs.flatten(), objective_jac,
                            Nsteps=Nsteps, direction='max', step_size=step_size, callback=callback_output_structure)
    return epsrs_optimum.reshape((num_dots, num_dots))

# %%
# Simulate optimal device
epsrs_optimum = simulate()
epsrs = epsr_parameterization(epsrs_optimum, bg_rho, design_region, rods)
_, ax, fig = viz_sim(epsrs, source, data, slices = input_slices + output_slices)
# Out:
# Epoch:   1/200 | Duration: 10.06 secs | Value: 1.232274e+01
# Epoch:   2/200 | Duration: 10.57 secs | Value: 1.586153e+01
# Epoch:   3/200 | Duration: 16.35 secs | Value: 1.929628e+01
# Epoch:   4/200 | Duration: 14.88 secs | Value: 1.991422e+01
# Epoch:   5/200 | Duration: 10.63 secs | Value: 1.859097e+01
# Epoch:   6/200 | Duration: 9.91 secs | Value: 1.799747e+01
# Epoch:   7/200 | Duration: 10.73 secs | Value: 1.825798e+01
# Epoch:   8/200 | Duration: 11.45 secs | Value: 1.907806e+01
# Epoch:   9/200 | Duration: 10.43 secs | Value: 2.007169e+01
# Epoch:  10/200 | Duration: 10.08 secs | Value: 2.070111e+01
# Epoch:  11/200 | Duration: 10.80 secs | Value: 2.063103e+01
# Epoch:  12/200 | Duration: 9.90 secs | Value: 2.021692e+01
# Epoch:  13/200 | Duration: 11.02 secs | Value: 2.001987e+01
# Epoch:  14/200 | Duration: 10.21 secs | Value: 2.023334e+01
# Epoch:  15/200 | Duration: 11.21 secs | Value: 2.074231e+01
# Epoch:  16/200 | Duration: 9.50 secs | Value: 2.127377e+01
# Epoch:  17/200 | Duration: 9.26 secs | Value: 2.155758e+01
# Epoch:  18/200 | Duration: 9.46 secs | Value: 2.154455e+01
# Epoch:  19/200 | Duration: 10.37 secs | Value: 2.143300e+01
# Epoch:  20/200 | Duration: 9.49 secs | Value: 2.144061e+01
# Epoch:  21/200 | Duration: 9.99 secs | Value: 2.164635e+01
# Epoch:  22/200 | Duration: 10.16 secs | Value: 2.198967e+01
# Epoch:  23/200 | Duration: 9.53 secs | Value: 2.232661e+01
# Epoch:  24/200 | Duration: 6.14 secs | Value: 2.252530e+01
# Epoch:  25/200 | Duration: 9.66 secs | Value: 2.257581e+01
# Epoch:  26/200 | Duration: 7.91 secs | Value: 2.259663e+01
# Epoch:  27/200 | Duration: 18.98 secs | Value: 2.271198e+01
# Epoch:  28/200 | Duration: 12.41 secs | Value: 2.294768e+01
# Epoch:  29/200 | Duration: 12.47 secs | Value: 2.322904e+01
# Epoch:  30/200 | Duration: 29.05 secs | Value: 2.345399e+01
# Epoch:  31/200 | Duration: 23.53 secs | Value: 2.358430e+01
# Epoch:  32/200 | Duration: 19.94 secs | Value: 2.367323e+01
# Epoch:  33/200 | Duration: 33.48 secs | Value: 2.380226e+01
# Epoch:  34/200 | Duration: 28.30 secs | Value: 2.400501e+01
# Epoch:  35/200 | Duration: 22.67 secs | Value: 2.424737e+01
# Epoch:  36/200 | Duration: 20.46 secs | Value: 2.446536e+01
# Epoch:  37/200 | Duration: 18.08 secs | Value: 2.462678e+01
# Epoch:  38/200 | Duration: 19.16 secs | Value: 2.476082e+01
# Epoch:  39/200 | Duration: 12.44 secs | Value: 2.492194e+01
# Epoch:  40/200 | Duration: 11.24 secs | Value: 2.513133e+01
# Epoch:  41/200 | Duration: 10.74 secs | Value: 2.536028e+01
# Epoch:  42/200 | Duration: 25.74 secs | Value: 2.556627e+01
# Epoch:  43/200 | Duration: 23.77 secs | Value: 2.573956e+01
# Epoch:  44/200 | Duration: 26.58 secs | Value: 2.590930e+01
# Epoch:  45/200 | Duration: 14.83 secs | Value: 2.610646e+01
# Epoch:  46/200 | Duration: 26.29 secs | Value: 2.633041e+01
# Epoch:  47/200 | Duration: 14.24 secs | Value: 2.655410e+01
# Epoch:  48/200 | Duration: 14.97 secs | Value: 2.675754e+01
# Epoch:  49/200 | Duration: 15.66 secs | Value: 2.695033e+01
# Epoch:  50/200 | Duration: 22.88 secs | Value: 2.715685e+01
# Epoch:  51/200 | Duration: 21.25 secs | Value: 2.738513e+01
# Epoch:  52/200 | Duration: 14.00 secs | Value: 2.761950e+01
# Epoch:  53/200 | Duration: 25.61 secs | Value: 2.784326e+01
# Epoch:  54/200 | Duration: 27.80 secs | Value: 2.806004e+01
# Epoch:  55/200 | Duration: 16.27 secs | Value: 2.828666e+01
# Epoch:  56/200 | Duration: 12.20 secs | Value: 2.853008e+01
# Epoch:  57/200 | Duration: 15.32 secs | Value: 2.878015e+01
# Epoch:  58/200 | Duration: 11.91 secs | Value: 2.902561e+01
# Epoch:  59/200 | Duration: 19.29 secs | Value: 2.926988e+01
# Epoch:  60/200 | Duration: 27.32 secs | Value: 2.952487e+01
# Epoch:  61/200 | Duration: 19.02 secs | Value: 2.979370e+01
# Epoch:  62/200 | Duration: 13.00 secs | Value: 3.006808e+01
# Epoch:  63/200 | Duration: 11.80 secs | Value: 3.034271e+01
# Epoch:  64/200 | Duration: 11.73 secs | Value: 3.062378e+01
# Epoch:  65/200 | Duration: 11.60 secs | Value: 3.091951e+01
# Epoch:  66/200 | Duration: 12.36 secs | Value: 3.122901e+01
# Epoch:  67/200 | Duration: 11.90 secs | Value: 3.154651e+01
# Epoch:  68/200 | Duration: 10.90 secs | Value: 3.187289e+01
# Epoch:  69/200 | Duration: 11.62 secs | Value: 3.221563e+01
# Epoch:  70/200 | Duration: 13.73 secs | Value: 3.257851e+01
# Epoch:  71/200 | Duration: 12.86 secs | Value: 3.295933e+01
# Epoch:  72/200 | Duration: 13.47 secs | Value: 3.335900e+01
# Epoch:  73/200 | Duration: 12.68 secs | Value: 3.378554e+01
# Epoch:  74/200 | Duration: 13.37 secs | Value: 3.424649e+01
# Epoch:  75/200 | Duration: 12.21 secs | Value: 3.474444e+01
# Epoch:  76/200 | Duration: 12.11 secs | Value: 3.528398e+01
# Epoch:  77/200 | Duration: 16.77 secs | Value: 3.587706e+01
# Epoch:  78/200 | Duration: 29.35 secs | Value: 3.653773e+01
# Epoch:  79/200 | Duration: 20.96 secs | Value: 3.727913e+01
# Epoch:  80/200 | Duration: 26.13 secs | Value: 3.812133e+01
# Epoch:  81/200 | Duration: 28.24 secs | Value: 3.909551e+01
# Epoch:  82/200 | Duration: 20.77 secs | Value: 4.023812e+01
# Epoch:  83/200 | Duration: 14.15 secs | Value: 4.159337e+01
# Epoch:  84/200 | Duration: 20.91 secs | Value: 4.322589e+01
# Epoch:  85/200 | Duration: 15.38 secs | Value: 4.521757e+01
# Epoch:  86/200 | Duration: 13.11 secs | Value: 4.764646e+01
# Epoch:  87/200 | Duration: 15.81 secs | Value: 5.053357e+01
# Epoch:  88/200 | Duration: 16.88 secs | Value: 5.363629e+01
# Epoch:  89/200 | Duration: 15.94 secs | Value: 5.594904e+01
# Epoch:  90/200 | Duration: 21.74 secs | Value: 5.554228e+01
# Epoch:  91/200 | Duration: 14.23 secs | Value: 5.437421e+01
# Epoch:  92/200 | Duration: 14.14 secs | Value: 5.538491e+01
# Epoch:  93/200 | Duration: 12.35 secs | Value: 5.758394e+01
# Epoch:  94/200 | Duration: 22.86 secs | Value: 5.995993e+01
# Epoch:  95/200 | Duration: 26.11 secs | Value: 6.129077e+01
# Epoch:  96/200 | Duration: 30.05 secs | Value: 6.175615e+01
# Epoch:  97/200 | Duration: 21.58 secs | Value: 6.189216e+01
# Epoch:  98/200 | Duration: 21.30 secs | Value: 6.212780e+01
# Epoch:  99/200 | Duration: 23.08 secs | Value: 6.271591e+01
# Epoch: 100/200 | Duration: 24.09 secs | Value: 6.360418e+01
# Epoch: 101/200 | Duration: 22.92 secs | Value: 6.473724e+01
# Epoch: 102/200 | Duration: 32.93 secs | Value: 6.583037e+01
# Epoch: 103/200 | Duration: 24.29 secs | Value: 6.657261e+01
# Epoch: 104/200 | Duration: 12.98 secs | Value: 6.670447e+01
# Epoch: 105/200 | Duration: 12.82 secs | Value: 6.660634e+01
# Epoch: 106/200 | Duration: 14.91 secs | Value: 6.670706e+01
# Epoch: 107/200 | Duration: 16.35 secs | Value: 6.733640e+01
# Epoch: 108/200 | Duration: 10.42 secs | Value: 6.820690e+01
# Epoch: 109/200 | Duration: 15.19 secs | Value: 6.896915e+01
# Epoch: 110/200 | Duration: 12.57 secs | Value: 6.948151e+01
# Epoch: 111/200 | Duration: 14.77 secs | Value: 6.977954e+01
# Epoch: 112/200 | Duration: 16.05 secs | Value: 7.009848e+01
# Epoch: 113/200 | Duration: 11.15 secs | Value: 7.054290e+01
# Epoch: 114/200 | Duration: 16.56 secs | Value: 7.108641e+01
# Epoch: 115/200 | Duration: 19.93 secs | Value: 7.166836e+01
# Epoch: 116/200 | Duration: 16.20 secs | Value: 7.218703e+01
# Epoch: 117/200 | Duration: 15.65 secs | Value: 7.255797e+01
# Epoch: 118/200 | Duration: 15.67 secs | Value: 7.281797e+01
# Epoch: 119/200 | Duration: 13.29 secs | Value: 7.306999e+01
# Epoch: 120/200 | Duration: 15.69 secs | Value: 7.335880e+01
# Epoch: 121/200 | Duration: 11.93 secs | Value: 7.347659e+01
# Epoch: 122/200 | Duration: 13.06 secs | Value: 7.320154e+01
# Epoch: 123/200 | Duration: 11.03 secs | Value: 7.390041e+01
# Epoch: 124/200 | Duration: 16.09 secs | Value: 7.495515e+01
# Epoch: 125/200 | Duration: 13.48 secs | Value: 7.451570e+01
# Epoch: 126/200 | Duration: 12.45 secs | Value: 7.511289e+01
# Epoch: 127/200 | Duration: 12.25 secs | Value: 7.575022e+01
# Epoch: 128/200 | Duration: 11.62 secs | Value: 7.561349e+01
# Epoch: 129/200 | Duration: 11.64 secs | Value: 7.654282e+01
# Epoch: 130/200 | Duration: 11.23 secs | Value: 7.664046e+01
# Epoch: 131/200 | Duration: 12.07 secs | Value: 7.692715e+01
# Epoch: 132/200 | Duration: 15.05 secs | Value: 7.757523e+01
# Epoch: 133/200 | Duration: 13.61 secs | Value: 7.755090e+01
# Epoch: 134/200 | Duration: 13.93 secs | Value: 7.821969e+01
# Epoch: 135/200 | Duration: 12.51 secs | Value: 7.858648e+01
# Epoch: 136/200 | Duration: 12.33 secs | Value: 7.884485e+01
# Epoch: 137/200 | Duration: 13.17 secs | Value: 7.948937e+01
# Epoch: 138/200 | Duration: 13.54 secs | Value: 7.967577e+01
# Epoch: 139/200 | Duration: 17.97 secs | Value: 8.018573e+01
# Epoch: 140/200 | Duration: 25.03 secs | Value: 8.067258e+01
# Epoch: 141/200 | Duration: 16.77 secs | Value: 8.100413e+01
# Epoch: 142/200 | Duration: 12.34 secs | Value: 8.164408e+01
# Epoch: 143/200 | Duration: 11.82 secs | Value: 8.206570e+01
# Epoch: 144/200 | Duration: 12.73 secs | Value: 8.252370e+01
# Epoch: 145/200 | Duration: 22.17 secs | Value: 8.317580e+01
# Epoch: 146/200 | Duration: 22.43 secs | Value: 8.367123e+01
# Epoch: 147/200 | Duration: 13.64 secs | Value: 8.423240e+01
# Epoch: 148/200 | Duration: 14.08 secs | Value: 8.496176e+01
# Epoch: 149/200 | Duration: 14.40 secs | Value: 8.562070e+01
# Epoch: 150/200 | Duration: 15.08 secs | Value: 8.624816e+01
# Epoch: 151/200 | Duration: 12.92 secs | Value: 8.700315e+01
# Epoch: 152/200 | Duration: 13.78 secs | Value: 8.787868e+01
# Epoch: 153/200 | Duration: 15.81 secs | Value: 8.874281e+01
# Epoch: 154/200 | Duration: 16.37 secs | Value: 8.959611e+01
# Epoch: 155/200 | Duration: 13.41 secs | Value: 9.050195e+01
# Epoch: 156/200 | Duration: 14.57 secs | Value: 9.138813e+01
# Epoch: 157/200 | Duration: 12.61 secs | Value: 9.222891e+01
# Epoch: 158/200 | Duration: 14.26 secs | Value: 9.281795e+01
# Epoch: 159/200 | Duration: 12.17 secs | Value: 9.326076e+01
# Epoch: 160/200 | Duration: 12.49 secs | Value: 9.440974e+01
# Epoch: 161/200 | Duration: 13.33 secs | Value: 9.641349e+01
# Epoch: 162/200 | Duration: 12.42 secs | Value: 9.795788e+01
# Epoch: 163/200 | Duration: 12.89 secs | Value: 9.866173e+01
# Epoch: 164/200 | Duration: 14.15 secs | Value: 9.878891e+01
# Epoch: 165/200 | Duration: 15.89 secs | Value: 9.905195e+01
# Epoch: 166/200 | Duration: 14.10 secs | Value: 1.009173e+02
# Epoch: 167/200 | Duration: 19.42 secs | Value: 1.033630e+02
# Epoch: 168/200 | Duration: 15.93 secs | Value: 1.048439e+02
# Epoch: 169/200 | Duration: 17.45 secs | Value: 1.052617e+02
# Epoch: 170/200 | Duration: 19.11 secs | Value: 1.048793e+02
# Epoch: 171/200 | Duration: 15.63 secs | Value: 1.055392e+02
# Epoch: 172/200 | Duration: 12.41 secs | Value: 1.085987e+02
# Epoch: 173/200 | Duration: 11.74 secs | Value: 1.113925e+02
# Epoch: 174/200 | Duration: 11.78 secs | Value: 1.124113e+02
# Epoch: 175/200 | Duration: 11.19 secs | Value: 1.118200e+02
# Epoch: 176/200 | Duration: 12.54 secs | Value: 1.110552e+02
# Epoch: 177/200 | Duration: 11.40 secs | Value: 1.139900e+02
# Epoch: 178/200 | Duration: 11.22 secs | Value: 1.182881e+02
# Epoch: 179/200 | Duration: 11.40 secs | Value: 1.201423e+02
# Epoch: 180/200 | Duration: 11.91 secs | Value: 1.195446e+02
# Epoch: 181/200 | Duration: 11.27 secs | Value: 1.174800e+02
# Epoch: 182/200 | Duration: 15.87 secs | Value: 1.199469e+02
# Epoch: 183/200 | Duration: 13.36 secs | Value: 1.258402e+02
# Epoch: 184/200 | Duration: 14.71 secs | Value: 1.284938e+02
# Epoch: 185/200 | Duration: 12.12 secs | Value: 1.277466e+02
# Epoch: 186/200 | Duration: 11.52 secs | Value: 1.242341e+02
# Epoch: 187/200 | Duration: 12.09 secs | Value: 1.266925e+02
# Epoch: 188/200 | Duration: 15.63 secs | Value: 1.344263e+02
# Epoch: 189/200 | Duration: 15.52 secs | Value: 1.377101e+02
# Epoch: 190/200 | Duration: 15.44 secs | Value: 1.366485e+02
# Epoch: 191/200 | Duration: 11.59 secs | Value: 1.310410e+02
# Epoch: 192/200 | Duration: 11.33 secs | Value: 1.341250e+02
# Epoch: 193/200 | Duration: 18.05 secs | Value: 1.441828e+02
# Epoch: 194/200 | Duration: 11.60 secs | Value: 1.479143e+02
# Epoch: 195/200 | Duration: 11.36 secs | Value: 1.461449e+02
# Epoch: 196/200 | Duration: 11.44 secs | Value: 1.374359e+02
# Epoch: 197/200 | Duration: 11.66 secs | Value: 1.433050e+02
# Epoch: 198/200 | Duration: 11.47 secs | Value: 1.552609e+02
# Epoch: 199/200 | Duration: 11.62 secs | Value: 1.594107e+02
# Epoch: 200/200 | Duration: 11.74 secs | Value: 1.581619e+02

# %%
obj = [1]
for i in range(1, Nsteps):
    Ex = np.loadtxt('spl/Ex_%03d.csv' % i, delimiter=',')
    epsr = np.loadtxt('spl/epsr_%03d.csv' % i, delimiter=',')
    obj.append(mode_overlap(Ex, probe) / normal)
    
    fig, axs = plt.subplots(2, 2, constrained_layout=True, figsize=(16,16))
    epsr[epsr >= epsr_train_max] = epsr_train_max
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
    abslt(Ex, outline=epsr_graph, ax=axs[0][0], cbar=True, vmax=Emax/2)
    axs[1][0].plot(obj)
    real(epsr, ax=axs[0][1], cmap='RdGy', cbar=True, vmin=emin, vmax=emax)
    axs[-1][-1].axis('off')
    plt.savefig('spl/normalized_%03d.png' % i, dpi=70)
    plt.close()

# %%
grid = (epsr_train_max-epsr_train_min) * (npa.arctan(epsrs_optimum)/np.pi + 0.5) + epsr_train_min
print(grid)
make_gif('sp2.gif', Nsteps, 'spl')
# Out:
# [[-1.0148 -1.0058 -0.9961 -0.9863 -0.9744 -0.9561 -0.9873 -1.1084 -1.0603
#   -0.9242 -0.9363 -0.9366 -0.9283 -0.9047 -0.9002]
#  [-1.0024 -0.9943 -0.9914 -0.9851 -0.9774 -0.9863 -1.0808 -1.0614 -0.9731
#   -0.9482 -0.9444 -0.9388 -0.9305 -0.9487 -0.9693]
#  [-1.0005 -0.9899 -0.9833 -0.9797 -0.9937 -1.0634 -1.0787 -1.0191 -0.9732
#   -0.9575 -0.9526 -0.9519 -0.9660 -0.9994 -1.0209]
#  [-1.0031 -0.9886 -0.9713 -0.9580 -1.0347 -1.0953 -1.0407 -0.9936 -0.9718
#   -0.9646 -0.9638 -0.9706 -0.9913 -1.0093 -1.0103]
#  [-1.0098 -0.9829 -0.9492 -0.9123 -0.9268 -1.0309 -0.9929 -0.9769 -0.9711
#   -0.9698 -0.9722 -0.9826 -0.9977 -1.0035 -1.0045]
#  [-1.0198 -0.9520 -0.9226 -0.9108 -0.9421 -0.9653 -0.9717 -0.9725 -0.9728
#   -0.9738 -0.9777 -0.9879 -1.0007 -1.0186 -1.0507]
#  [-0.9036 -0.9448 -0.9635 -0.9576 -0.9621 -0.9688 -0.9729 -0.9751 -0.9763
#   -0.9771 -0.9795 -0.9858 -0.9941 -1.0085 -1.0818]
#  [-1.0413 -1.0488 -0.9997 -0.9789 -0.9730 -0.9748 -0.9776 -0.9796 -0.9806
#   -0.9790 -0.9743 -0.9713 -0.9657 -0.9292 -1.0226]
#  [-1.1742 -1.0376 -0.9994 -0.9821 -0.9782 -0.9802 -0.9832 -0.9859 -0.9869
#   -0.9790 -0.9558 -0.9452 -0.9342 -0.9204 -1.0923]
#  [-1.0201 -0.9984 -0.9918 -0.9843 -0.9824 -0.9853 -0.9895 -0.9948 -1.0010
#   -0.9867 -0.9315 -0.9450 -0.9629 -1.0108 -1.0756]
#  [-1.0131 -1.0115 -1.0069 -0.9851 -0.9838 -0.9879 -0.9935 -1.0026 -1.0263
#   -1.0240 -0.9605 -0.9743 -0.9918 -1.0090 -1.0158]
#  [-1.0931 -1.0892 -0.9827 -0.9728 -0.9784 -0.9836 -0.9901 -1.0002 -1.0112
#   -0.9941 -0.9854 -0.9920 -0.9971 -0.9940 -0.9873]
#  [-1.1176 -0.9539 -0.9467 -0.9614 -0.9693 -0.9751 -0.9834 -0.9998 -0.9969
#   -0.9760 -0.9901 -0.9963 -0.9964 -0.9902 -0.9751]
#  [-0.9476 -0.9173 -0.9398 -0.9533 -0.9619 -0.9681 -0.9789 -1.0426 -0.9399
#   -0.9841 -0.9940 -0.9914 -0.9897 -0.9851 -0.9487]
#  [-0.8720 -0.9117 -0.9354 -0.9505 -0.9587 -0.9639 -0.9659 -0.8976 -0.9142
#   -1.0377 -0.9876 -0.9832 -0.9740 -0.9483 -0.9926]]
